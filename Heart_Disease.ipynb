# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("heart.csv")

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
sns.barplot(df,x="cp",y="target")
# Out:
# <Axes: xlabel='cp', ylabel='target'>

# %%
df.drop(index=267,inplace=True)

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  301.000000  301.000000  301.000000  301.000000  301.000000  301.000000
# mean    54.378738    0.681063    0.966777  131.641196  246.531561    0.149502
# std      9.033793    0.466841    1.032259   17.579842   51.836761    0.357176
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  301.000000  301.000000  301.000000  301.000000  301.000000  301.000000
# mean     0.524917  149.830565    0.328904    1.043189    1.398671    0.720930
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 301 entries, 0 to 878
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       301 non-null    int64
#  1   sex       301 non-null    int64
#  2   cp        301 non-null    int64
#  3   trestbps  301 non-null    int64
#  4   chol      301 non-null    int64
#  5   fbs       301 non-null    int64
#  6   restecg   301 non-null    int64
#  7   thalach   301 non-null    int64
#  8   exang     301 non-null    int64
#  9   oldpeak   301 non-null    float64
#  10  slope     301 non-null    int64
#  11  ca        301 non-null    int64
#  12  thal      301 non-null    int64
#  13  target    301 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 35.3 KB

# %%
df.corr()["target"]
# Out:
# age        -0.217563
# sex        -0.281912
# cp          0.430167
# trestbps   -0.149068
# chol       -0.082270
# fbs        -0.028406
# restecg     0.138601
# thalach     0.416569
# exang      -0.439354
# oldpeak    -0.430131
# slope       0.342514
# ca         -0.412747
# thal       -0.345797
# target      1.000000
# Name: target, dtype: float64

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
from sklearn.preprocessing import FunctionTransformer
transformer=FunctionTransformer(func=np.log1p)
chol_new=transformer.transform(df["chol"])
trestbps_new=transformer.transform(df["trestbps"])

# %%
df["chol_new"]=chol_new
df["trestbps_new"]=trestbps_new

# %%
sns.distplot(df["trestbps_new"],hist=False)
# Out:
# <Axes: xlabel='trestbps_new', ylabel='Density'>

# %%
df.drop(["chol","fbs","chol_new","trestbps"],axis=1,inplace=True)

# %%
df
# Out:
#      age  sex  cp  restecg  thalach  exang  oldpeak  slope  ca  thal  target  \
# 0     52    1   0        1      168      0      1.0      2   2     3       0
# 1     53    1   0        0      155      1      3.1      0   0     3       0
# 2     70    1   0        1      125      1      2.6      0   0     3       0
# 3     61    1   0        1      161      0      0.0      2   1     3       0
# 4     62    0   0        1      106      0      1.9      1   3     2       0
# ..   ...  ...  ..      ...      ...    ...      ...    ...  ..   ...     ...
# 723   68    0   2        0      115      0      1.5      1   0     2       1
# 733   44    0   2        1      175      0      0.6      1   0     2       1
# 739   52    1   0        1      161      1      0.0      2   1     3       0
# 843   59    1   3        0      125      0      0.0      2   0     2       0
# 878   54    1   0        1      113      0      1.4      1   1     3       0
#
#      trestbps_new
# 0        4.836282
# ...

# %%
X=df.drop("target",axis=1)
Y=df["target"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

# %%
ct=ColumnTransformer(transformers=[('trf1',StandardScaler(),["age","thalach","trestbps_new"])],remainder="passthrough")

# %%
X_train
# Out:
#      age  sex  cp  restecg  thalach  exang  oldpeak  slope  ca  thal  \
# 256   35    0   0        1      182      0      1.4      2   0     2
# 163   48    1   0        0      166      0      0.5      1   0     3
# 279   41    0   1        1      168      0      0.0      2   1     2
# 85    44    1   1        1      170      0      0.0      2   0     2
# 135   58    0   0        0      146      1      2.8      1   2     1
# ..   ...  ...  ..      ...      ...    ...      ...    ...  ..   ...
# 268   58    1   2        0      173      0      3.2      2   2     3
# 77    63    1   0        0      144      1      4.0      2   2     3
# 125   60    0   3        1      171      0      0.9      2   0     2
# 528   59    1   3        0      145      0      4.2      0   0     3
# 119   42    1   1        1      162      0      0.0      2   0     2
#
#      trestbps_new
# 256      4.934474
# 163      4.828314
# 279      4.663439
# 85       4.795791
# 135      5.141664
# ..            ...
# ...

# %%
X_train_scaled=ct.fit_transform(X_train)
X_test_scaled=ct.transform(X_test)

# %%
X_train_scaled=pd.DataFrame(X_train_scaled,columns=ct.get_feature_names_out())
X_train_scaled
X_test_scaled=pd.DataFrame(X_test_scaled,columns=ct.get_feature_names_out())
X_test_scaled
# Out:
#     trf1__age  trf1__thalach  trf1__trestbps_new  remainder__sex  \
# 0   -0.022429       0.401153            0.133870             0.0
# 1    1.185980      -0.439498           -0.618210             1.0
# 2    0.307137      -1.058926           -1.304289             1.0
# 3    1.076124      -0.749212            0.598445             0.0
# 4   -0.132284       0.091439            0.013358             1.0
# ..        ...            ...                 ...             ...
# 56   0.416992       0.666622           -1.162257             1.0
# 57   1.515545      -1.545618           -0.618210             0.0
# 58   1.076124      -0.793457            0.875601             1.0
# 59  -1.230837       1.374539           -0.953854             1.0
# 60  -2.109680      -0.881946           -0.618210             1.0
#
#     remainder__cp  remainder__restecg  remainder__exang  remainder__oldpeak  \
# 0             1.0                 0.0               1.0                 0.0
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(16, activation="relu", input_shape=(X_train_scaled.shape[1],)))

model.add(Dense(8, activation="relu"))

model.add(Dense(1, activation="sigmoid"))

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = model.fit(
    X_train_scaled,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 0.6458 - loss: 0.6527 - val_accuracy: 0.6667 - val_loss: 0.6515
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6979 - loss: 0.6452 - val_accuracy: 0.6458 - val_loss: 0.6470
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7240 - loss: 0.6374 - val_accuracy: 0.6458 - val_loss: 0.6432
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7344 - loss: 0.6292 - val_accuracy: 0.6667 - val_loss: 0.6387
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7448 - loss: 0.6211 - val_accuracy: 0.6667 - val_loss: 0.6343
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7604 - loss: 0.6126 - val_accuracy: 0.6667 - val_loss: 0.6284
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7812 - loss: 0.6009 - val_accuracy: 0.6458 - val_loss: 0.6201
# Epoch 8/100
# ...

# %%
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8361 - loss: 0.5302
# Test Loss: 0.5301591753959656
# Test Accuracy: 0.8360655903816223

# %%
y_pred_prob = model.predict(X_test_scaled)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step

# %%
y_pred = (y_pred_prob > 0.5).astype(int)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.83        26
#            1       0.93      0.77      0.84        35
#
#     accuracy                           0.84        61
#    macro avg       0.84      0.85      0.84        61
# weighted avg       0.85      0.84      0.84        61

# %%
model.save("heart_disease_ann.keras")

# %%
import joblib

joblib.dump(ct, "transformer.pkl")
# Out:
# ['transformer.pkl']
